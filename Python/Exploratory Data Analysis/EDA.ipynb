# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/enricokoegler/Desktop/Data Analysis Bootcamp/Python/Exploratory Data Analysis/world_population.csv')
pd.reset_option("all")
pd.set_option('display.float_format', lambda x: '%.2f' % x)
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0        41128771.00      38972230.00      33753499.00      28189672.00
# 1         2842321.00       2866849.00       2882481.00       2913399.00
# ...

# %%
df.describe()
# Out:
#         Rank  2022 Population  2020 Population  2015 Population  \
# count 234.00           230.00           233.00           230.00
# mean  117.50      34632250.88      33600710.95      32066004.16
# std    67.69     137889172.44     135873196.61     131507146.34
# min     1.00           510.00           520.00           564.00
# 25%    59.25        419738.50        406471.00        394295.00
# 50%   117.50       5762857.00       5456681.00       5244415.00
# 75%   175.75      22653719.00      21522626.00      19730853.75
# max   234.00    1425887337.00    1424929781.00    1393715448.00
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count           227.00           227.00           229.00           229.00
# mean       30270164.48      26840495.26      19330463.93      16282884.78
# std       126074183.54     113352454.57      81309624.96      69345465.54
# min             596.00           651.00           700.00           733.00
# ...

# %%
df.isnull().sum()
# Out:
# Rank                           0
# CCA3                           0
# Country                        0
# Capital                        0
# Continent                      0
# 2022 Population                4
# 2020 Population                1
# 2015 Population                4
# 2010 Population                7
# 2000 Population                7
# 1990 Population                5
# 1980 Population                5
# 1970 Population                4
# Area (km²)                     2
# Density (per km²)              4
# Growth Rate                    2
# World Population Percentage    0
# dtype: int64

# %%
df[df.isnull().any(axis=1)].head()
# Out:
#     Rank CCA3            Country  Capital      Continent  2022 Population  \
# 13    91  AZE         Azerbaijan     Baku           Asia      10358074.00
# 42    28  COL           Colombia   Bogota  South America      51874024.00
# 59   152  GNQ  Equatorial Guinea   Malabo         Africa       1674908.00
# 62   159  SWZ           Eswatini  Mbabane         Africa              NaN
# 72   142  GMB             Gambia   Banjul         Africa       2705992.00
#
#     2020 Population  2015 Population  2010 Population  2000 Population  \
# 13              NaN       9863480.00       9237202.00       8190337.00
# 42      50930662.00      47119728.00              NaN      39215135.00
# 59       1596049.00              NaN       1094524.00        684977.00
# 62       1180655.00       1133936.00       1099920.00       1030496.00
# 72       2573995.00       2253133.00              NaN              NaN
#
#     1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
df[df['2022 Population'].isnull()]
# Out:
#      Rank CCA3      Country    Capital Continent  2022 Population  \
# 62    159  SWZ     Eswatini    Mbabane    Africa              NaN
# 154   120  NOR       Norway       Oslo    Europe              NaN
# 157   222  PLW        Palau  Ngerulmud   Oceania              NaN
# 207   155  TLS  Timor-Leste       Dili      Asia              NaN
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# 62        1180655.00       1133936.00       1099920.00       1030496.00
# 154       5379839.00              NaN       4889741.00       4491202.00
# 157         17972.00         17794.00         18540.00         19726.00
# 207       1299995.00       1205813.00       1088486.00              NaN
#
#      1990 Population  1980 Population  1970 Population  Area (km²)  \
# 62         854011.00        598564.00        442865.00    17364.00
# 154       4241636.00       4085776.00       3875546.00   323802.00
# 157         15293.00         12252.00         11366.00      459.00
# ...

# %%
df['World Population Percentage'].sum()
# Out:
# 99.93

# %%
df.sort_values('2022 Population', ascending=False).head(10)
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 221     3  USA  United States  Washington, D.C.  North America
# 93      4  IDN      Indonesia           Jakarta           Asia
# 156     5  PAK       Pakistan         Islamabad           Asia
# 149     6  NGA        Nigeria             Abuja         Africa
# 27      7  BRA         Brazil          Brasilia  South America
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 171     9  RUS         Russia            Moscow         Europe
# 131    10  MEX         Mexico       Mexico City  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41     1425887337.00    1424929781.00    1393715448.00    1348191368.00
# 92     1417173173.00    1396387127.00    1322866505.00    1240613620.00
# ...

# %%
df['Continent'].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Oceania', 'North America',
#        'South America'], dtype=object)

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)
df.iloc[:, 5:19].corr()
# Out:
#                              2022 Population  2020 Population  \
# 2022 Population                         1.00             1.00
# 2020 Population                         1.00             1.00
# 2015 Population                         1.00             1.00
# 2010 Population                         1.00             1.00
# 2000 Population                         0.99             1.00
# 1990 Population                         0.99             0.99
# 1980 Population                         0.99             0.99
# 1970 Population                         0.97             0.98
# Area (km²)                              0.45             0.45
# Density (per km²)                      -0.03            -0.03
# Growth Rate                            -0.02            -0.03
# World Population Percentage             1.00             1.00
#
#                              2015 Population  2010 Population  \
# 2022 Population                         1.00             1.00
# ...

# %%
sns.heatmap(df.iloc[:, 5:19].corr(), annot=True)
plt.rcParams['figure.figsize'] = (8,8)
plt.show()

# %%
df2 = df.drop(['CCA3', 'Country', 'Capital'], axis=1).groupby('Continent').sum()
df2
# Out:
#                Rank  2022 Population  2020 Population  2015 Population  \
# Continent
# Africa         5253    1425529262.00    1360671810.00    1156663993.00
# Asia           3878    4720041978.00    4652801584.00    4458250182.00
# Europe         6225     737713219.00     745792196.00     736345252.00
# North America  6437     600296136.00     594236593.00     570383850.00
# Oceania        4336      45020499.00      43933426.00      40403283.00
# South America  1366     436816608.00     431530043.00     413134396.00
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# Africa           1020502655.00     817508493.00     637110013.00
# Asia             4187125190.00    3706718415.00    2334719776.00
# Europe            735613934.00     726066600.00     709689789.00
# North America     542720651.00     486069584.00     421266425.00
# Oceania            37102764.00      31222778.00      26743822.00
# ...

# %%
plt.pie(df2['2022 Population'], labels=df2.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fe698f02310>,
# ...
#  [Text(0.9306727059453908, 0.5863858067930058, 'Africa'),
#   Text(-1.0867241775769407, 0.17038357276956625, 'Asia'),
#   Text(0.4547990607583743, -1.0015776626569208, 'Europe'),
#   Text(0.897283939260429, -0.6363030192803479, 'North America'),
#   Text(1.0285844550517587, -0.3898897521426757, 'Oceania'),
#   Text(1.0837156973255375, -0.18857435501738884, 'South America')])

# %%
df2[df2.columns[1:9]]
# Out:
#                2022 Population  2020 Population  2015 Population  \
# Continent
# Africa           1425529262.00    1360671810.00    1156663993.00
# Asia             4720041978.00    4652801584.00    4458250182.00
# Europe            737713219.00     745792196.00     736345252.00
# North America     600296136.00     594236593.00     570383850.00
# Oceania            45020499.00      43933426.00      40403283.00
# South America     436816608.00     431530043.00     413134396.00
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# Africa           1020502655.00     817508493.00     637110013.00
# Asia             4187125190.00    3706718415.00    2334719776.00
# Europe            735613934.00     726066600.00     709689789.00
# North America     542720651.00     486069584.00     421266425.00
# Oceania            37102764.00      31222778.00      26743822.00
# South America     348262142.00     325206553.00     297146415.00
#
# ...

# %%
plt.figure(figsize=(10, 6))
#df2[df2.columns[1:9]].iloc[:,::-1].transpose().plot()
plt.plot(df2[df2.columns[1:9]].iloc[:,::-1].transpose())

# %%
df.boxplot(figsize=(20,10))
# Out:
# <Axes: >

# %%
df.select_dtypes(include='number').columns
# Out:
# Index(['Rank', '2022 Population', '2020 Population', '2015 Population',
#        '2010 Population', '2000 Population', '1990 Population',
#        '1980 Population', '1970 Population', 'Area (km²)', 'Density (per km²)',
#        'Growth Rate', 'World Population Percentage'],
#       dtype='object')
